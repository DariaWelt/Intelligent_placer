# %% [markdown]
# # Intelligent placer usage examplpe
# The code below is weak and did not contain exception handling because it is not functional part of tool. The only mission of this script is demonstration of lib working.

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from matplotlib import patches

from intelligent_placer_lib import check_image

# %% [markdown]
# ## Algorithm metrics
# If run tests on dataset:
# - 17/18 tests are passed, so accuracy is 94.44%
# - true positive = 10
# - true negative = 7
# - false positive = 0
# - false nevative = 1
# - in 3/18 tests in final segmentation one item (class=7) is missed (img4)
#
# BUT there are only one case with placement that is possible with rotation and impossible without it for now

# %% [markdown]
# If parameter `verbose=True` is selected, the check_image function displays the intermediate algorithm results:
# - detected contours
# - polygon contour
# - per contour segmentation
# - final segmentation results
# - the mask of objects placement in the polygon

# %% [markdown]
# Firstly let's look at the simple example with one object that could be placed into polygon.

# %%
image_path_example1 = 'test/data/IMG_1_figure_1_1.jpg'
image = np.array(Image.open(image_path_example1))
plt.imshow(image)
plt.show()

# %%
# %%time
check_image(image_path_example1, verbose=True)
# Out:
# Wall time: 33.7 s
# True

# %% [markdown]
# Secondly there are cases where objects are segmented incorrectly (as a circular cap)

# %%
image_path_example2 = 'test/data/IMG_12_figure_2_1.jpg'
image = np.array(Image.open(image_path_example2))
plt.imshow(image)
plt.show()

# %%
# %%time
check_image(image_path_example2, verbose=True)
# Out:
# Wall time: 43.8 s
# True

# %% [markdown]
# Let's look at an example when objects (several) can't be placed into figure

# %%
image_path_example3 = 'test/data/IMG_2_figure_2_0.jpg'
image = np.array(Image.open(image_path_example3))
plt.imshow(image)
plt.show()

# %%
# %%time
check_image(image_path_example3, verbose=True)
# Out:
# Wall time: 52.6 s
# False

# %% [markdown]
# Finally, consider an example where the placer algorithm works incorrect

# %%
image_path_example4 = 'test/data/IMG_10_figure_0_1.jpg'
image = np.array(Image.open(image_path_example4))
plt.imshow(image)
plt.show()

# %%
# %%time
check_image(image_path_example4, verbose=True)
# Out:
# Wall time: 19.3 s
# False

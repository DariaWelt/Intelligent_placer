# %% [markdown]
# # Intelligent placer usage examplpe
# The code below is weak and did not contain exception handling because it is not functional part of tool. The only mission of this script is demonstration of lib working.

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

from intelligent_placer_lib import check_image

# %% [markdown]
# ## Algorithm metrics
# If run tests on dataset:
# - 30/32 tests are passed, so accuracy is 93.75%
# - true positive = 17
# - true negative = 13
# - false positive = 1
# - false nevative = 1
# - in 6/32 tests in final segmentation one item (class=7) is missed (img4, img5)
#
# BUT there are only one case with placement that is possible only when shadows are considered

# %% [markdown]
# If parameter `verbose=True` is selected, the check_image function displays the intermediate algorithm results:
# - detected contours
# - polygon contour
# - per contour segmentation
# - final segmentation results
# - the mask of objects placement in the polygon

# %% [markdown]
# Firstly let's look at the simple example with one object that could be placed into polygon.

# %%
image_path_example1 = 'test/data/IMG_10_figure_0_1.jpg'
image = np.array(Image.open(image_path_example1))
plt.imshow(image)
plt.show()

# %%
# %%time
check_image(image_path_example1, verbose=True)
# Out:
# CPU times: user 21.3 s, sys: 735 ms, total: 22.1 s
# Wall time: 20.8 s
# True

# %% [markdown]
# Secondly there are cases where objects are segmented incorrectly (flash drive segmented as a green cap - class 6)

# %%
image_path_example2 = 'test/data/IMG_2_figure_4_1.jpg'
image = np.array(Image.open(image_path_example2))
plt.imshow(image)
plt.show()

# %%
# %%time
check_image(image_path_example2, verbose=True)
# Out:
# /home/daria/PycharmProjects/Intelligent_placer/intelligent_placer_lib/intelligent_placer.py:26: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   cur_sequence = np.random.permutation(objects_masks)
# <__array_function__ internals>:180: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# CPU times: user 1min 16s, sys: 1.1 s, total: 1min 17s
# Wall time: 1min 18s
# True

# %% [markdown]
# Let's look at an example when objects (several) can't be placed into figure

# %%
image_path_example3 = 'test/data/IMG_0_figure_4_0.jpg'
image = np.array(Image.open(image_path_example3))
plt.imshow(image)
plt.show()

# %%
# %%time
check_image(image_path_example3, verbose=True)

# %% [markdown]
# So... when placement is impossible brute force solution takes a long-long time
